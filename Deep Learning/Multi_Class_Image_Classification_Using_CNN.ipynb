# %% [markdown]
# # Objective: Classifify images in three categories

# %% [markdown]
# ## Step1: Import All dependencies

# %%
# !pip install  -q tensorflow
# !pip install  -q  gradio

# %%
# import the necessary packages
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.utils import to_categorical

from sklearn.model_selection import train_test_split

from imutils import paths
import matplotlib.pyplot as plt
import numpy as np

import random
import cv2
import os

import warnings
from tqdm import tqdm_notebook as tqdm
import itertools
import tensorflow as tf
print(tf.__version__)
warnings.filterwarnings("ignore")
SEED = 42   # set random seed
# Out:
# 2.18.0

# %% [markdown]
# ## Step 2: Load Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/MyDrive/Deep Learning Project /4. Image Classification Using CNN")

# %%
# # Extract dataset.rar file (Run only First Time)
# !pip install patool
# import patoolib
# patoolib.extract_archive("dataset.rar")
# patoolib.extract_archive("test_examples.rar")

# %%
# !dir
# Out:
# cnn_model_100.h5  dataset.rar					    test_examples
# cnn_model_30.h5   FINAL_CNN.html				    test_examples.rar
# dataset		  Multi_Class_Image_Classification_Using_CNN.ipynb  Untitled0.ipynb

# %% [markdown]
# ## Step 3: Build CNN Model

# %%
# create CNN model
class LeNet:
    @staticmethod
    def build(width, height, depth, classes):

        # initialize the model
        model = Sequential()
        inputShape = (height, width, depth) # (h, h, chanel)

        # if we are using "channels first", update the input shape
        if K.image_data_format() == "channels_first":
            inputShape = (depth, height, width)

        # first set of CONV => RELU => POOL layers
        model.add(Conv2D(50, (5, 5), padding="same", input_shape=inputShape))
        model.add(Activation("relu"))
        model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

        # second set of CONV => RELU => POOL layers
        model.add(Conv2D(150, (5, 5), padding="same"))
        model.add(Activation("relu"))
        model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

        # third set of CONV => RELU => POOL layers
        model.add(Conv2D(200, (5, 5), padding="same"))
        model.add(Activation("relu"))
        model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

        # ------------------------ANN-----------------------
        # first (and only) set of FC => RELU layers
        model.add(Flatten())
        model.add(Dense(2000))
        model.add(Activation("relu"))

        # softmax classifier
        model.add(Dense(classes))
        model.add(Activation("softmax"))

        # return the constructed network architecture
        return model

# %% [markdown]
# ## Step 4: Data Reading

# %%
DATASET = "dataset"  # this folde must contain three subfolder with images
MODEL = "Scene.model" # name to store the model on disk
PLOT = "plot.png" # plot name

# %%
# initialize the data and labels
print("[INFO] loading images...")
data = []  # x
labels = [] # y

# grab the image paths and randomly shuffle them
imagePaths = sorted(list(paths.list_images("dataset")))
random.seed(42)
random.shuffle(imagePaths)

# progress bar
with tqdm(total=len(imagePaths)) as pbar:
    # loop over the input images
    for idx, imagePath in enumerate(imagePaths):
        # load the image, pre-process it, and store it in the data list
        image = cv2.imread(imagePath)
        image = cv2.resize(image, (28, 28))
        image = img_to_array(image)
        data.append(image)

        # extract the class label from the image path and update the
        # labels list
        label = imagePath.split(os.path.sep)[-2]

        if label == "Buildings":
            label = 0
        elif label == "Forest":
            label = 1
        elif label == "Sea":
            label = 2
        labels.append(label)
        # update the progressbar
        pbar.update(1)
# Out:
# [INFO] loading images...
#   0%|          | 0/1326 [00:00<?, ?it/s]

# %%
# check shape of single image
data[0].shape

# %%
data[0]

# %% [markdown]
# ## Step 5: Data Spliting

# %%
# perform data normalisation
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)

# %%
data[0]

# %%
# Split the data into train test
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=0.25, random_state=42)

# %%
# verify shapes
print(trainX.shape)
print(testX.shape)
print(trainY.shape)
print(testY.shape)

# %%
trainY[0] # 1

# %%
# Perform one hot label encoding
trainY = to_categorical(trainY, num_classes=3)
testY = to_categorical(testY, num_classes=3)

# %%
trainY[0]

# %% [markdown]
# ## Step 6: Data Preprocessing (Augumentation)

# %%
# construct the image generator for data augmentation
aug = ImageDataGenerator(rotation_range=30,
                         width_shift_range=0.1,
                         height_shift_range=0.1,
                         shear_range=0.2,
                         zoom_range=0.2,
                         horizontal_flip=True,
                         fill_mode="nearest")

# %% [markdown]
# ## Step 7: Compile and Training

# %%
INIT_LR = 1e-3
BS = 64

# initialize the model
print("[INFO] compiling model...")
model = LeNet.build(width=28, height=28, depth=3, classes=3)
opt = Adam(learning_rate=INIT_LR)

model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
print("[INFO] model complied...")

# %%
print(model.summary())

# %%
# train the network

EPOCH  = 100
print("[INFO] training network...")
H = model.fit(x=aug.flow(trainX, trainY, batch_size=BS),
              validation_data=(testX, testY),
              steps_per_epoch=len(trainX) // BS,
              epochs=EPOCH,
              verbose=1)

# save the model and label binarizer to disk
print("[INFO] serializing network ...")
model.save("cnn_model_{}.h5".format(EPOCH))
# Out:
# [INFO] training network...
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 385ms/step - accuracy: 0.3117 - loss: 1.2549 - val_accuracy: 0.3343 - val_loss: 1.0698
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3438 - loss: 1.0767 - val_accuracy: 0.5331 - val_loss: 1.0033
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.5318 - loss: 0.9468 - val_accuracy: 0.6807 - val_loss: 0.7303
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7188 - loss: 0.6974 - val_accuracy: 0.7108 - val_loss: 0.6921
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.6613 - loss: 0.7843 - val_accuracy: 0.7500 - val_loss: 0.5811
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8281 - loss: 0.4522 - val_accuracy: 0.6596 - val_loss: 0.6944
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.6946 - loss: 0.6936 - val_accuracy: 0.7440 - val_loss: 0.6210
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7656 - loss: 0.6160 - val_accuracy: 0.7801 - val_loss: 0.5826
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.7261 - loss: 0.6467 - val_accuracy: 0.7620 - val_loss: 0.5381
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7812 - loss: 0.5476 - val_accuracy: 0.7651 - val_loss: 0.5409
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.7946 - loss: 0.5268 - val_accuracy: 0.8223 - val_loss: 0.4444
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7344 - loss: 0.6213 - val_accuracy: 0.7741 - val_loss: 0.5265
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7889 - loss: 0.5354 - val_accuracy: 0.7741 - val_loss: 0.5593
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8125 - loss: 0.3721 - val_accuracy: 0.7801 - val_loss: 0.5463
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8403 - loss: 0.4468 - val_accuracy: 0.6928 - val_loss: 0.5693
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7969 - loss: 0.4788 - val_accuracy: 0.8163 - val_loss: 0.4521
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.7869 - loss: 0.5513 - val_accuracy: 0.8343 - val_loss: 0.4047
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7812 - loss: 0.6018 - val_accuracy: 0.8133 - val_loss: 0.4496
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8629 - loss: 0.3678 - val_accuracy: 0.7139 - val_loss: 0.6121
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7031 - loss: 0.6210 - val_accuracy: 0.8434 - val_loss: 0.3998
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8178 - loss: 0.4862 - val_accuracy: 0.8012 - val_loss: 0.4506
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8125 - loss: 0.4276 - val_accuracy: 0.7711 - val_loss: 0.4914
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8535 - loss: 0.4241 - val_accuracy: 0.8253 - val_loss: 0.4456
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8125 - loss: 0.4053 - val_accuracy: 0.8042 - val_loss: 0.5031
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8575 - loss: 0.4018 - val_accuracy: 0.8253 - val_loss: 0.4638
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8281 - loss: 0.4090 - val_accuracy: 0.8434 - val_loss: 0.4084
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8374 - loss: 0.4156 - val_accuracy: 0.8343 - val_loss: 0.4380
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8906 - loss: 0.2599 - val_accuracy: 0.7651 - val_loss: 0.5908
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8263 - loss: 0.4595 - val_accuracy: 0.7831 - val_loss: 0.5721
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8281 - loss: 0.4208 - val_accuracy: 0.7831 - val_loss: 0.5728
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8556 - loss: 0.3769 - val_accuracy: 0.8614 - val_loss: 0.3621
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8281 - loss: 0.2948 - val_accuracy: 0.8434 - val_loss: 0.4329
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8680 - loss: 0.3428 - val_accuracy: 0.7741 - val_loss: 0.6321
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8438 - loss: 0.3839 - val_accuracy: 0.7982 - val_loss: 0.5920
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8822 - loss: 0.3229 - val_accuracy: 0.8283 - val_loss: 0.4994
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9375 - loss: 0.1751 - val_accuracy: 0.8163 - val_loss: 0.5431
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8890 - loss: 0.2909 - val_accuracy: 0.7831 - val_loss: 0.5776
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8438 - loss: 0.4542 - val_accuracy: 0.8675 - val_loss: 0.3415
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8593 - loss: 0.3659 - val_accuracy: 0.8193 - val_loss: 0.4235
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8281 - loss: 0.4473 - val_accuracy: 0.8645 - val_loss: 0.3368
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8643 - loss: 0.3622 - val_accuracy: 0.8223 - val_loss: 0.4441
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8750 - loss: 0.3307 - val_accuracy: 0.8464 - val_loss: 0.3887
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8866 - loss: 0.2856 - val_accuracy: 0.8675 - val_loss: 0.3864
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8594 - loss: 0.2980 - val_accuracy: 0.8343 - val_loss: 0.4457
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8881 - loss: 0.3024 - val_accuracy: 0.7440 - val_loss: 0.6381
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8594 - loss: 0.3505 - val_accuracy: 0.7892 - val_loss: 0.5294
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8870 - loss: 0.2942 - val_accuracy: 0.7922 - val_loss: 0.4974
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7941 - loss: 0.2628 - val_accuracy: 0.8795 - val_loss: 0.3391
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8624 - loss: 0.3503 - val_accuracy: 0.8253 - val_loss: 0.4161
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9375 - loss: 0.3001 - val_accuracy: 0.7952 - val_loss: 0.4875
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8586 - loss: 0.3277 - val_accuracy: 0.7500 - val_loss: 0.8965
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8438 - loss: 0.4091 - val_accuracy: 0.8494 - val_loss: 0.4297
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8761 - loss: 0.2980 - val_accuracy: 0.8584 - val_loss: 0.4219
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9062 - loss: 0.2793 - val_accuracy: 0.8072 - val_loss: 0.5752
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8897 - loss: 0.2703 - val_accuracy: 0.8795 - val_loss: 0.3300
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8125 - loss: 0.3347 - val_accuracy: 0.8705 - val_loss: 0.3419
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9086 - loss: 0.2294 - val_accuracy: 0.8645 - val_loss: 0.3542
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9531 - loss: 0.1690 - val_accuracy: 0.8554 - val_loss: 0.3991
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8791 - loss: 0.3034 - val_accuracy: 0.7139 - val_loss: 0.6919
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8438 - loss: 0.4165 - val_accuracy: 0.7831 - val_loss: 0.5300
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8925 - loss: 0.2507 - val_accuracy: 0.8524 - val_loss: 0.4284
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8438 - loss: 0.3016 - val_accuracy: 0.8524 - val_loss: 0.4005
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8993 - loss: 0.2439 - val_accuracy: 0.8313 - val_loss: 0.4577
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9531 - loss: 0.1573 - val_accuracy: 0.8223 - val_loss: 0.4887
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8891 - loss: 0.2598 - val_accuracy: 0.8072 - val_loss: 0.4854
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9375 - loss: 0.2183 - val_accuracy: 0.7319 - val_loss: 0.6680
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8815 - loss: 0.2968 - val_accuracy: 0.8404 - val_loss: 0.3578
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0809 - val_accuracy: 0.8343 - val_loss: 0.3965
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9211 - loss: 0.2047 - val_accuracy: 0.7982 - val_loss: 0.5851
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9688 - loss: 0.1561 - val_accuracy: 0.7590 - val_loss: 0.6834
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8944 - loss: 0.2432 - val_accuracy: 0.8313 - val_loss: 0.4946
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9062 - loss: 0.2045 - val_accuracy: 0.8735 - val_loss: 0.3454
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.9195 - loss: 0.2199 - val_accuracy: 0.8464 - val_loss: 0.4484
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8906 - loss: 0.2972 - val_accuracy: 0.8373 - val_loss: 0.4838
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9319 - loss: 0.1813 - val_accuracy: 0.8614 - val_loss: 0.4433
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9531 - loss: 0.1742 - val_accuracy: 0.8434 - val_loss: 0.4823
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9220 - loss: 0.1966 - val_accuracy: 0.8675 - val_loss: 0.4119
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9688 - loss: 0.1306 - val_accuracy: 0.8705 - val_loss: 0.4224
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9327 - loss: 0.2057 - val_accuracy: 0.8524 - val_loss: 0.3929
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9844 - loss: 0.0585 - val_accuracy: 0.8554 - val_loss: 0.4196
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9403 - loss: 0.1892 - val_accuracy: 0.8193 - val_loss: 0.4759
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9219 - loss: 0.2042 - val_accuracy: 0.8163 - val_loss: 0.5020
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9506 - loss: 0.1357 - val_accuracy: 0.8404 - val_loss: 0.4416
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8750 - loss: 0.2916 - val_accuracy: 0.8313 - val_loss: 0.4714
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9286 - loss: 0.2000 - val_accuracy: 0.8464 - val_loss: 0.4838
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9062 - loss: 0.2117 - val_accuracy: 0.8614 - val_loss: 0.4263
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9293 - loss: 0.1641 - val_accuracy: 0.8494 - val_loss: 0.4008
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8281 - loss: 0.4115 - val_accuracy: 0.8283 - val_loss: 0.5265
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9259 - loss: 0.2004 - val_accuracy: 0.7681 - val_loss: 0.6578
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8906 - loss: 0.2678 - val_accuracy: 0.7590 - val_loss: 0.6740
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9151 - loss: 0.2153 - val_accuracy: 0.8373 - val_loss: 0.4549
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9375 - loss: 0.1896 - val_accuracy: 0.8434 - val_loss: 0.4832
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9484 - loss: 0.1531 - val_accuracy: 0.8042 - val_loss: 0.6760
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9844 - loss: 0.0943 - val_accuracy: 0.7982 - val_loss: 0.7257
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9255 - loss: 0.2011 - val_accuracy: 0.8434 - val_loss: 0.4416
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9531 - loss: 0.1434 - val_accuracy: 0.8554 - val_loss: 0.3802
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9144 - loss: 0.2178 - val_accuracy: 0.8434 - val_loss: 0.4034
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9531 - loss: 0.1409 - val_accuracy: 0.8404 - val_loss: 0.3954
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9339 - loss: 0.1641 - val_accuracy: 0.8313 - val_loss: 0.5166
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9688 - loss: 0.0926 - val_accuracy: 0.8343 - val_loss: 0.5292
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [INFO] serializing network ...

# %% [markdown]
# ## Step 8:  Model Evaluation

# %%
# plot the training and validation accuracy  https://justpaste.it/ed3e5
N = np.arange(0, EPOCH )
plt.style.use("ggplot")
plt.figure(figsize = [10,8])
plt.plot(N, H.history["accuracy"], label="train_acc")
plt.plot(N, H.history["val_accuracy"], label="val_acc")
plt.title("CNN: Training and Validation Accuracy")
plt.xlabel("Epoch #", weight="bold")
plt.ylabel("Accuracy", weight="bold")
plt.legend()
plt.show()

# %%
# plot the training and validation loss
N = np.arange(0, EPOCH)
plt.style.use("ggplot")
plt.figure(figsize = [10,8])
plt.plot(N, H.history["loss"], label="train_loss")
plt.plot(N, H.history["val_loss"], label="val_loss")
plt.title("CNN: Training & Validation Loss")
plt.xlabel("Epoch #", weight="bold")
plt.ylabel("Loss", weight="bold")
plt.legend()
plt.show()

# %% [markdown]
# ### Confusion Matrix (Homework)

# %% [markdown]
# ## Step 9: Prediction on Unseen Data

# %%
def display_img(img):  # https://justpaste.it/hc5ip
    fig = plt.figure(figsize=(12,10))
    ax = fig.add_subplot(111)
    ax.imshow(img)

import imutils

# %%
# grab the image paths and randomly shuffle themt
testImagePaths = sorted(list(paths.list_images('test_examples')))   # data folder with 2 categorical folders

all_class = ["Buildings", "Forest", "Sea"]


# progress bar
with tqdm(total=len(testImagePaths)) as pbar:

    for imagePath in testImagePaths:

        # load the image
        image = cv2.imread(imagePath)
        orig = image.copy()

        # pre-process the image for classification
        image = cv2.resize(image, (28, 28))
        image = image.astype("float") / 255.0
        image = img_to_array(image)
        image = np.expand_dims(image, axis=0)

        # classify the input image
        prd_conf= model.predict(image)[0] # [[0.1 , 0.8 , 0.1]]
        print(prd_conf)

        # build the label
        label = all_class[np.argmax(prd_conf)] #[b f s]-> f
        proba = prd_conf[np.argmax(prd_conf)] # [0.1 , 0.8 , 0.1]  -> 0.8

        label = "{}: {:.2f}%".format(label, proba * 100)

        # draw the label on the image
        output = imutils.resize(orig, width=400)
        cv2.putText(output, label, (10, 25),  cv2.FONT_HERSHEY_SIMPLEX,
            0.7, (255, 0, 0), 2)

        # convert img to rgb format and display in notebook
        img = cv2.cvtColor(output, cv2.COLOR_BGR2RGB)
        display_img(img)

        pbar.update(1)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Step 10: Deployment on Gradio

# %%
import gradio as gr    # https://justpaste.it/bdyzt
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
import numpy as np
import argparse
import imutils
import cv2
import matplotlib.pyplot as plt
from imutils import paths
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/Deep Learning Projects/2. Image Classification using CNN")

# # load the model
print("[INFO] loading network and...")
model = load_model("cnn_model_{}.h5".format(100))
# Out:
# [INFO] loading network and...
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
def predict_image(image):
    # pre-process the image for classification
    image = cv2.resize(image, (28, 28))
    image = image.astype("float") / 255.0
    image = img_to_array(image)
    image = np.expand_dims(image, axis=0)

    preds = model.predict(image)[0]
    result = dict()
    result["Buildings"] = round(float(list(preds)[0]), 3)
    result["Forest"] = round(float(list(preds)[1]), 3)
    result["Sea"] = round(float(list(preds)[2]), 3)

    print(result)
    return result

# %%
im = gr.Image()
label = gr.Label(num_top_classes=3)
gr.Interface(fn=predict_image,
             inputs=im,
             outputs=label,
             title="CNN Demo").launch(share=True, debug=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://e66e503df0895c03bf.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://e66e503df0895c03bf.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 764ms/step
# {'Buildings': 0.005, 'Forest': 0.029, 'Sea': 0.966}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# {'Buildings': 0.342, 'Forest': 0.002, 'Sea': 0.656}

# %% [markdown]
# ## The End
