# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import numpy as np
import re

# %%
# list of text documents
text = ["The  quick dev brown fox jumped the over the lazy dog dev"]

# %%
# create the transform
vectorizer = CountVectorizer()

# %%
# tokenize and build vocab
vectorizer.fit(text)
# Out:
# TfidfVectorizer()

# %%
# summarize
print(vectorizer.vocabulary_)
# Out:
# {'the': 8, 'quick': 7, 'dev': 1, 'brown': 0, 'fox': 3, 'jumped': 4, 'over': 6, 'lazy': 5, 'dog': 2}

# %%
# encode document
vector = vectorizer.transform(text)
# summarize encoded vector
print(vector.shape)
print(type(vector))
print(vector.toarray())
# Out:
# (1, 9)
# <class 'scipy.sparse._csr.csr_matrix'>
# [[0.2236068  0.4472136  0.2236068  0.2236068  0.2236068  0.2236068
#   0.2236068  0.2236068  0.67082039]]

# %%
sentences = ["Machine learning is great.",
             "Natural Language Processing is a complex  field",
             "Natural Language Processing is used in machine learning"]

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

vectorizer = CountVectorizer(analyzer = "word", 
                             tokenizer = None, 
                             preprocessor = None, 
                             stop_words = ["is" , "machine"],
                             max_features = 5000)

# %%
train_data_features = vectorizer.fit_transform(sentences)
print(vectorizer.vocabulary_)
# Out:
# {'learning': 5, 'great': 2, 'natural': 6, 'language': 4, 'processing': 7, 'complex': 0, 'field': 1, 'used': 8, 'in': 3}

# %%
train_data_features.toarray()
# Out:
# array([[0.        , 0.        , 0.79596054, 0.        , 0.        ,
#         0.60534851, 0.        , 0.        , 0.        ],
#        [0.51741994, 0.51741994, 0.        , 0.        , 0.3935112 ,
#         0.        , 0.3935112 , 0.3935112 , 0.        ],
#        [0.        , 0.        , 0.        , 0.48148213, 0.36617957,
#         0.36617957, 0.36617957, 0.36617957, 0.48148213]])

# %%
vectorizer.transform(["Machine  Deep learning Machine learning is dev   is great",
                      "Natural Language sup Processing is a complex field dec dec dec ",
                        "Natural Language great Processing is used in machine learning"]).toarray()
# Out:
# array([[0.        , 0.        , 0.54935123, 0.        , 0.        ,
#         0.83559154, 0.        , 0.        , 0.        ],
#        [0.51741994, 0.51741994, 0.        , 0.        , 0.3935112 ,
#         0.        , 0.3935112 , 0.3935112 , 0.        ],
#        [0.        , 0.        , 0.43381609, 0.43381609, 0.32992832,
#         0.32992832, 0.32992832, 0.32992832, 0.43381609]])
