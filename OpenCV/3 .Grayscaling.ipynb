# %% [markdown]
# ## Grayscaling
#
# #### Grayscaling is process by which an image is converted from a full color to shades of grey (black & white)
#
# In OpenCV, many functions grayscale images before processing. This is done because it simplifies the image, acting almost as a noise reduction and increasing processing time as there is less information in the image.
#
# ### Let convert our color image to greyscale

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
# !dir
# Out:
#  Volume in drive W is Work
#  Volume Serial Number is 263A-C986
#
#  Directory of W:\Trainings\Image Processing\OpenCv Basic
#
# 15-03-2025  12:53 PM    <DIR>          .
# 12-05-2024  02:53 PM    <DIR>          ..
# 08-06-2024  05:20 PM    <DIR>          .ipynb_checkpoints
# 09-03-2025  03:24 PM            46,937 1. Reading, writing and displaying images.ipynb
# 28-07-2024  11:37 AM             3,421 10. Cropping.ipynb
# 14-09-2024  07:54 PM            31,829 11. Video Processing.ipynb
# 14-01-2023  05:08 PM             4,410 12. Convolutions and Blurring.ipynb
# 08-11-2023  12:49 PM             4,034 13. Canny Edge Detectionm.ipynb
# 09-03-2025  04:12 PM           164,646 2. Drawing-on-Images.ipynb
# 15-03-2025  12:53 PM           685,193 3 .Grayscaling.ipynb
# 14-09-2024  06:58 PM             6,700 4. Color Spaces.ipynb
# 28-07-2024  09:53 AM           336,951 5. Histograms.ipynb
# 28-07-2024  10:03 AM             6,058 6. Translations.ipynb
# 28-07-2024  10:57 AM             4,737 7. Rotations.ipynb
# 14-09-2024  07:07 PM             8,479 8. Scaling, re-sizing and interpolations.ipynb
# 28-07-2024  11:34 AM             4,785 9. Bitwise Operations and Masking.ipynb
# 02-12-2023  06:55 PM           234,517 ASDFASD.jpg
# 09-03-2025  02:58 PM    <DIR>          DATA
# 08-06-2024  05:20 PM           162,099 sdf.jpg
#               15 File(s)      1,704,796 bytes
#                4 Dir(s)  310,679,351,296 bytes free

# %%
# Load our input image
image = cv2.imread("DATA/two_people.jpg") # BGR

# %%
image

type(image)
# Out:
# numpy.ndarray

# %%
def img_display(image):
    cv2.imshow('ouput window', image)
    cv2.waitKey()
    cv2.destroyAllWindows()

# %%
img_display(image)

# %%
image.shape
# Out:
# (534, 800, 3)

# %%
plt.imshow(image) # RGB

# %%
# We use cvtColor, to convert to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
gray_image.shape
# Out:
# (534, 800)

# %%
plt.imshow(gray_image, cmap="gray")

# %%
cv2.imshow('Grayscale', gray_image)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
#Another method faster method
img = cv2.imread('DATA/test1.jpg',0)

# %%
cv2.imshow('Grayscale', img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img = cv2.imread('DATA/input.jpg')

# %%
def dis(img):
    cv2.imshow('Grayscale', img)
    cv2.waitKey()
    cv2.destroyAllWindows()

# %%
dis(img)

# %%
cv2.destroyAllWindows()
